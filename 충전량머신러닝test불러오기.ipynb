# %%
import joblib as job
import pymssql
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# C:\Users\bit\anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working

# %%
loaded_model_ln = job.load('./충전량머신러닝testModel.pkl')

# %% [markdown]
# <h4>DB 연결</h4>

# %%
conn = pymssql.connect(server="14.32.18.226", user="as", password="1234", database="YL1")

# %%
cursor = conn.cursor()

# %%
# # insert 쿼리
# cursor.execute("insert into test_predict_spend value (?,?)", Date_temp, pred_model_result)
# conn.commit()

# %%
model_dp = pd.DataFrame(columns=['Date', 'Charge'])

# %%
for Date_temp in range(1, 41):
    X = float(Date_temp)
    pred_model_result = loaded_model_ln.predict([[X]])
    n = pred_model_result.astype('int32')
    X = int(X)
    n = n[0]
    n = n[0]
    n = int(n)
    cursor.execute("insert into test_predict_charge values (%d,%d)", (X, n))

# %%
conn.commit()

# %%
data = pd.read_sql("select * from test_predict_charge", conn)

# %%
data
# Out:
#    date     charge
# 0     1    7219016
# 1     2   18356658
# 2     3   29494300
# 3     4   40631942
# 4     5   51769583
# 5     6   62907225
# 6     7   74044867
# 7     8   85182509
# 8     9   96320150
# 9    10  107457792
# 10   11  118595434
# 11   12  129733076
# 12   13  140870717
# 13   14  152008359
# 14   15  163146001
# 15   16  174283643
# 16   17  185421284
# 17   18  196558926
# 18   19  207696568
# 19   20  218834210
# 20   21  229971851
# 21   22  241109493
# 22   23  252247135
# 23   24  263384777
# 24   25  274522418
# 25   26  285660060
# 26   27  296797702
# 27   28  307935344
# 28   29  319072985
# 29   30  330210627
# 30   31  341348269
# 31   32  352485911
# 32   33  363623552
# 33   34  374761194
# 34   35  385898836
# 35   36  397036478
# 36   37  408174119
# 37   38  419311761
# 38   39  430449403
# 39   40  441587045

# %%
# 그래프 폰트 설정
import matplotlib.font_manager as fm
path = 'C:\\Users\\bit\\Downloads\\NanumBarunGothic.ttf'
fp = fm.FontProperties(fname=path, size=11)

# %%
X = data['date']
y = data['spend']
plt.plot(X, y, 'o')
plt.title("월별 지역화폐 사용량", fontproperties=fp)
plt.xlabel("월", fontproperties=fp)
plt.ylabel("사용량(100억)", fontproperties=fp)
# plt.yticks([10000000,20000000,30000000,40000000,50000000,60000000])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'spend'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-e4976742b73b> in <module>
#       1 X = data['date']
# ----> 2 y = data['spend']
#       3 plt.plot(X, y, 'o')
#       4 plt.title("월별 지역화폐 사용량", fontproperties=fp)
#       5 plt.xlabel("월", fontproperties=fp)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'spend'
