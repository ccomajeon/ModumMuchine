# %%
import joblib as job
import pymssql
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# C:\Users\bit\anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working

# %%
loaded_model_ln = job.load('./사용량머신러닝testModel.pkl')

# %% [markdown]
# <h4>DB 연결</h4>

# %%
conn = pymssql.connect(server="14.32.18.226", user="as", password="1234", database="YL1")

# %%
cursor = conn.cursor()

# %%
# # insert 쿼리
# cursor.execute("insert into test_predict_spend value (?,?)", Date_temp, pred_model_result)
# conn.commit()

# %%
model_dp = pd.DataFrame(columns=['Date', 'Spend'])

# %%
for Date_temp in range(1, 41):
    X = float(Date_temp)
    pred_model_result = loaded_model_ln.predict([[X]])
    n = pred_model_result.astype('int32')
    X = int(X)
    n = n[0]
    n = n[0]
    n = int(n)
    cursor.execute("insert into test_predict_spend values (%d,%d)", (X, n))

# %%
conn.commit()

# %%
data = pd.read_sql("select * from test_predict_spend", conn)

# %%
data
# Out:
#     date        spend
# 0    1.0    3579707.0
# 1    2.0   11378123.0
# 2    3.0   19176539.0
# 3    4.0   26974955.0
# 4    5.0   34773370.0
# 5    6.0   42571786.0
# 6    7.0   50370202.0
# 7    8.0   58168618.0
# 8    9.0   65967033.0
# 9   10.0   73765449.0
# 10  11.0   81563865.0
# 11  12.0   89362281.0
# 12  13.0   97160696.0
# 13  14.0  104959112.0
# 14  15.0  112757528.0
# 15  16.0  120555944.0
# 16  17.0  128354359.0
# 17  18.0  136152775.0
# 18  19.0  143951191.0
# 19  20.0  151749607.0
# 20  21.0  159548022.0
# 21  22.0  167346438.0
# 22  23.0  175144854.0
# 23  24.0  182943270.0
# 24  25.0  190741685.0
# 25  26.0  198540101.0
# 26  27.0  206338517.0
# 27  28.0  214136933.0
# 28  29.0  221935348.0
# 29  30.0  229733764.0
# 30  31.0  237532180.0
# 31  32.0  245330596.0
# 32  33.0  253129011.0
# 33  34.0  260927427.0
# 34  35.0  268725843.0
# 35  36.0  276524259.0
# 36  37.0  284322674.0
# 37  38.0  292121090.0
# 38  39.0  299919506.0
# 39  40.0  307717922.0

# %%
# 그래프 폰트 설정
import matplotlib.font_manager as fm
path = 'C:\\Users\\bit\\Downloads\\NanumBarunGothic.ttf'
fp = fm.FontProperties(fname=path, size=11)

# %%
X = data['date']
y = data['spend']
plt.plot(X, y, 'o')
plt.title("월별 지역화폐 사용량", fontproperties=fp)
plt.xlabel("월", fontproperties=fp)
plt.ylabel("사용량(100억)", fontproperties=fp)
# plt.yticks([10000000,20000000,30000000,40000000,50000000,60000000])
plt.show()
